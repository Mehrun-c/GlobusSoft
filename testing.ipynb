# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehrun-c/GlobusSoft/blob/main/testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import numpy as np
import pickle
import argparse

# %%
# This cell is now empty as its contents have been moved to a_RK6heAtksb

# %%
# This cell is now empty as its contents have been moved to a_RK6heAtksb

# %%
# This cell is now empty as its contents have been moved to a_RK6heAtksb

# %%
# This cell is now empty as its contents have been moved to a_RK6heAtksb

# %%
def main():
    import argparse
    parser = argparse.ArgumentParser(
        description="Face Verification using HOG + SVM"
    )
    parser.add_argument("--img1",      required=True,        help="Path to first face image")
    parser.add_argument("--img2",      required=True,        help="Path to second face image")
    parser.add_argument("--model",     default="face_auth_model.pkl",
                        help="Path to trained model (default: face_auth_model.pkl)")
    parser.add_argument("--threshold", type=float, default=0.72,
                        help="Cosine similarity threshold (default: 0.72)")
    args = parser.parse_args()

    result = verify_faces(args.img1, args.img2, args.model, args.threshold)
    print_result(result)

# %%
from google.colab import files
files.download("face_auth_model.pkl")

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-eafa1928-4f95-47d7-84bc-8d9720e8a96b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eafa1928-4f95-47d7-84bc-8d9720e8a96b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c7dc13f4-0d75-4ca6-8574-7bb86529f76d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7dc13f4-0d75-4ca6-8574-7bb86529f76d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pickle

with open("face_auth_model.pkl", "rb") as f:
    model = pickle.load(f)

print("Model loaded")
# Out:
# Model loaded

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'face1.jpg.jpeg', '.ipynb_checkpoints', 'face_auth_model.pkl', 'face2.jpg.jpeg', 'sample_data']

# %%
IMG1 = "/content/face1.jpg.jpeg"
IMG2 = "/content/face2.jpg.jpeg"

# %%
import cv2

img1 = cv2.imread("/content/face1.jpg.jpeg")
img2 = cv2.imread("/content/face2.jpg.jpeg")

print(img1.shape)
print(img2.shape)
# Out:
# (360, 540, 3)
# (493, 740, 3)

# %%
if __name__ == "__main__":
    if _is_colab():
        # ── COLAB: edit these two paths and run the cell ──────────────────────
        img1 = "/content/face1.jpg.jpeg"   # <-- change to your image path
        img2 = "/content/face2.jpg.jpeg"   # <-- change to your image path
        run_in_colab(img1, img2)
    else:
        # ── Terminal: python task2_test.py --img1 a.jpg --img2 b.jpg ──────────
        main()
# Out:
# [INFO] Model loaded from 'face_auth_model.pkl'
#
# ========== Face Verification Result ==========
#   Verification Result : DIFFERENT PERSON
#   Similarity Score    : 0.4176
#   Identity (Image 1)  : George W Bush
#   Identity (Image 2)  : George W Bush
#   Bounding Box Img 1  : (np.int32(184), np.int32(65), np.int32(142), np.int32(142))
#   Bounding Box Img 2  : (np.int32(231), np.int32(69), np.int32(293), np.int32(293))
# ...
